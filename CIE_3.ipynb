# %% [markdown]
# <a href="https://colab.research.google.com/github/simran2352/suhana-/blob/main/CIE_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/auto-mpg (1).csv')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.drop('car name',axis=1,inplace=True)

# %%
from sklearn preprocessing import LabelEncoder
le=LabelEncoder()
df['origin']=le.fit_transform(df['origin'])

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipython-input-4116506308.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
x=df.iloc[:,1:8]
y=df[['mpg']]

# %%
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0         130    3504          12.0          70
# 1            8         350.0         165    3693          11.5          70
# 2            8         318.0         150    3436          11.0          70
# 3            8         304.0         150    3433          12.0          70
# 4            8         302.0         140    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0          86    2790          15.6          82
# 394          4          97.0          52    2130          24.6          82
# 395          4         135.0          84    2295          11.6          82
# 396          4         120.0          79    2625          18.6          82
# 397          4         119.0          82    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
y
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,)

# %%
x_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 30           4         140.0          90    2264          15.5          71
# 187          8         305.0         140    4215          13.0          76
# 186          4         101.0          83    2202          15.3          76
# 277          6         163.0         133    3410          15.8          78
# 338          4         135.0          84    2490          15.7          81
# ..         ...           ...         ...     ...           ...         ...
# 194          6         232.0          90    3085          17.6          76
# 170          4         140.0          78    2592          18.5          75
# 369          4         112.0          88    2395          18.0          82
# 24           6         199.0          90    2648          15.0          70
# 223          8         318.0         145    4140          13.7          77
#
#      origin
# 30        1
# 187       1
# 186       2
# 277       2
# ...

# %%
x_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 208          8         318.0         150    3940          13.2          76
# 35           6         250.0         100    3329          15.5          71
# 91           8         400.0         150    4464          12.0          73
# 57           4         113.0          95    2278          15.5          72
# 40           8         351.0         153    4154          13.5          71
# ..         ...           ...         ...     ...           ...         ...
# 225          6         250.0         110    3520          16.4          77
# 325          4          90.0          48    2085          21.7          80
# 107          6         232.0         100    2789          15.0          73
# 387          6         262.0          85    3015          17.0          82
# 146          4          90.0          75    2125          14.5          74
#
#      origin
# 208       1
# 35        1
# 91        1
# 57        3
# ...

# %%
y_train
# Out:
#       mpg
# 340  25.8
# 90   12.0
# 0    18.0
# 21   24.0
# 359  28.1
# ..    ...
# 314  26.4
# 213  13.0
# 78   21.0
# 58   25.0
# 144  31.0
#
# [318 rows x 1 columns]

# %%
y_test
# Out:
#       mpg
# 208  13.0
# 35   17.0
# 91   13.0
# 57   24.0
# 40   14.0
# ..    ...
# 225  17.5
# 325  44.3
# 107  18.0
# 387  38.0
# 146  28.0
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([[16.79590042],
#        [17.2956523 ],
#        [12.47606795],
#        [26.31833054],
#        [12.18570564],
#        [31.60051885],
#        [ 9.14585882],
#        [18.01975549],
#        [10.85187741],
#        [29.64532552],
#        [15.10535215],
#        [31.07310105],
#        [20.1225558 ],
#        [21.79731504],
#        [26.46025165],
#        [31.02751212],
#        [30.45024709],
#        [22.30955765],
#        [13.4387167 ],
#        [17.50790829],
#        [24.14803478],
#        [30.50112316],
#        [12.4989912 ],
#        [14.18887393],
#        [33.86403873],
#        [22.51760793],
#        [15.23194173],
#        [25.94304923],
#        [28.64168215],
#        [19.74229501],
#        [28.75011284],
#        [17.21621983],
#        [20.92120848],
#        [23.64868816],
#        [25.74181332],
#        [31.45846847],
#        [21.91319257],
#        [12.29293452],
#        [31.479938  ],
#        [27.19330958],
#        [30.75584542],
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)

# %%
print("mean squared error:",mse)
print("mean absolute error:",mae)
print("r2-Score:",r2)
print("Root mean squared error:",rmse)
# Out:
# mean squared error: 15.613478839543877
# mean absolute error: 2.92026206841913
# r2-Score: 0.7759442469498348
# Root mean squared error: 3.9513894821371225
